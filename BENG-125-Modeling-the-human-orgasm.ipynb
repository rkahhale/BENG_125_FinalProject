# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
u = [0]
v = [0]
t = np.arange(0,5,.000001)
squigly = -.000001
alpha = 1
b = 1
c = 1
g = 1

for i in range(0,14):
    u.append(u[i]+ ((2*squigly*u[i]) + (alpha*v[i])))
    omega = np.sin(t[i])
    v.append(v[i]+ ((b*v[i]) + (c*(u[i]**3)) + (g*np.sin(omega*t[i]))))
print(u)
print(v)
plt.plot(u,v)
plt.show()
#goes from being logarithmic to liniear at 13
# Out:
# [0, 0.0, 0.0, 9.999999999998333e-07, 4.999997999998168e-06, 1.5999987999995334e-05, 4.1999956000120005e-05, 9.89998720044845e-05, 0.00021899967408734524, 0.00046599923722344465, 0.0009679983179991919, 0.001980996508745077, 0.004016993707271439, 0.0080999957684406, 0.016278064577930212]
# [0, 0.0, 9.999999999998333e-07, 3.999999999998334e-06, 1.0999999999993168e-05, 2.600000000010067e-05, 5.7000000004276496e-05, 0.00012000000008260476, 0.00024700000113544757, 0.0005020000127742218, 0.0010130001267425212, 0.0020360011605193794, 0.004083010095156575, 0.008178085009481152, 0.01636970145912904]

# %%
u = [0]
v = [0]
t = np.arange(0,50)
m1 = 1
m2 = 1
m3 = 1
m4 = 1
for i in range(0,50): 
    u.append(u[i]+ ((-1*m1*u[i])-(m2*v[i])+np.sin(t[i])))
    v.append(v[i]+ ((-1*m3*u[i])-(m4*v[i])))
plt.plot(u,v)
plt.show()
#goes from being logarithmic to liniear at 13
